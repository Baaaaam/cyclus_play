# %%
from cymetric import timeseries as com
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/importlib/_bootstrap.py:222: QAWarning: pyne.data is not yet QA compliant.
#   return f(*args, **kwds)
# /opt/local/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/importlib/_bootstrap.py:222: QAWarning: pyne.material is not yet QA compliant.
#   return f(*args, **kwds)
# /opt/local/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/importlib/_bootstrap.py:222: QAWarning: pyne.enrichment is not yet QA compliant.
#   return f(*args, **kwds)

# %%
import cymetric as cym
db = cym.dbopen('cyclus.sqlite')
ev = cym.Evaluator(db=db, write=False)

# %%
from cymetric import graphs

# %%
cym.graphs.flow_graph(ev)

# %%
from cymetric import timeseries as tim

# %%
uox = tim.transactions(ev, commodities=['waste'])
uox_u5 = tim.transactions(ev, commodities=['waste'], nucs=['235U'])
uox_u5['Mass'] = uox_u5['Mass']/uox['Mass']
uox_u5['Mass'].dropna()
# Out:
# 3      0.004403
# 21     0.004711
# 39     0.004381
# 57     0.002914
# 75     0.004178
# 93     0.003244
# 111    0.002813
# 129    0.001315
# 147    0.004004
# 165    0.001714
# 183    0.002824
# 201    0.003688
# 219    0.003197
# 237    0.001965
# 255    0.003487
# 273    0.004036
# 291    0.002954
# 309    0.003327
# 327    0.002923
# 345    0.002428
# 363    0.003399
# 381    0.002921
# 399    0.003320
# 417    0.002487
# 435    0.004678
# 453    0.003169
# 471    0.002479
# 489    0.001053
# 507    0.002813
# 525    0.003731
# 543    0.003184
# 561    0.004030
# 579    0.003113
# 597    0.003007
# 615    0.001694
# 633    0.003689
# 651    0.001443
# 669    0.002730
# 687    0.003946
# 705    0.001987
# Name: Mass, dtype: float64

# %%
uox_spent = tim.transactions(ev, commodities=['c_uox_spent'])
uox_u5_spent = tim.transactions(ev, commodities=['c_uox_spent'], nucs=['235U'])
uox_u5_spent['Mass'] = uox_u5_spent['Mass']/uox_spent['Mass']
uox_u5_spent['Mass'].dropna()
# Out:
# 20     0.060200
# 38     0.060200
# 56     0.060200
# 74     0.060200
# 92     0.060200
# 110    0.060200
# 128    0.060200
# 146    0.060200
# 164    0.060200
# 182    0.060200
# 200    0.060200
# 218    0.060200
# 236    0.060200
# 254    0.060200
# 272    0.060200
# 290    0.060200
# 308    0.060200
# 326    0.060200
# 344    0.060200
# 362    0.060200
# 380    0.060200
# 398    0.060200
# 416    0.060200
# 434    0.060200
# 452    0.060200
# 470    0.060200
# 488    0.060200
# 506    0.060200
# 524    0.060200
# 542    0.060200
# 560    0.060200
# 578    0.060200
# 596    0.060200
# 614    0.060200
# 632    0.060200
# 650    0.060200
# 668    0.060200
# 686    0.060200
# 704    0.060200
# 720    0.068067
# Name: Mass, dtype: float64

# %%
uox[(uox.Mass != 0)]
# Out:
#      Time          Mass
# 3       3  2.514335e+06
# 21     21  9.457573e+05
# 39     39  8.314454e+05
# 57     57  5.407532e+05
# 75     75  7.737514e+05
# 93     93  5.868644e+05
# 111   111  5.280279e+05
# 129   129  3.915599e+05
# 147   147  7.305034e+05
# 165   165  4.205017e+05
# 183   183  5.293471e+05
# 201   201  6.629967e+05
# 219   219  5.798682e+05
# 237   237  4.410018e+05
# 255   255  6.262200e+05
# 273   273  7.381291e+05
# 291   291  5.459260e+05
# 309   309  5.998244e+05
# 327   327  5.419420e+05
# 345   345  4.845710e+05
# 363   363  6.114348e+05
# 381   381  5.416427e+05
# 399   399  5.987008e+05
# 417   417  4.908318e+05
# 435   435  9.330419e+05
# 453   453  5.757532e+05
# 471   471  4.898954e+05
# 489   489  3.746063e+05
# 507   507  5.279804e+05
# 525   525  6.714706e+05
# 543   543  5.779693e+05
# 561   561  7.366463e+05
# 579   579  5.677006e+05
# 597   597  5.529764e+05
# 615   615  4.189127e+05
# 633   633  6.632685e+05
# 651   651  4.003863e+05
# ...

# %%
powe = tim.get_power(ev)
#powe[(powe.Value != 0)]
powe
# Out:
# /Users/mouginot/.local/lib/python3.5/site-packages/cymetric/timeseries.py:226: UserWarning: no faciity provided
#   warnings.warn(wng_msg, UserWarning)
#      Time   Value
# 0       0     0.0
# 1       1     0.0
# 2       2  1000.0
# 3       3  1000.0
# 4       4  1000.0
# 5       5  1000.0
# 6       6  1000.0
# 7       7  1000.0
# 8       8  1000.0
# 9       9  1000.0
# 10     10  1000.0
# 11     11  1000.0
# 12     12  1000.0
# 13     13  1000.0
# 14     14  1000.0
# 15     15  1000.0
# 16     16  1000.0
# 17     17  1000.0
# 18     18  1000.0
# 19     19  1000.0
# 20     20  1000.0
# 21     21  1000.0
# 22     22  1000.0
# 23     23  1000.0
# 24     24  1000.0
# 25     25  1000.0
# 26     26  1000.0
# 27     27  1000.0
# 28     28  1000.0
# 29     29  1000.0
# ..    ...     ...
# 970   970     0.0
# 971   971     0.0
# 972   972     0.0
# 973   973     0.0
# 974   974     0.0
# 975   975     0.0
# 976   976     0.0
# 977   977     0.0
# 978   978     0.0
# 979   979     0.0
# ...
