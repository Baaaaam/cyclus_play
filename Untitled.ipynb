# %%
import cymetric as cym
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import cy_fast_timed_analysis as ana_t
#import cy_fast_analysis as ana
from cymetric import convenient_interface as cvi
# %matplotlib inline
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/importlib/_bootstrap.py:222: QAWarning: pyne.data is not yet QA compliant.
#   return f(*args, **kwds)
# /opt/local/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/importlib/_bootstrap.py:222: QAWarning: pyne.material is not yet QA compliant.
#   return f(*args, **kwds)
# /opt/local/Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/importlib/_bootstrap.py:222: QAWarning: pyne.enrichment is not yet QA compliant.
#   return f(*args, **kwds)

# %%
#load db in a evaler
db_unat = cym.dbopen('cyclus_unat.sqlite')
db_unat_ss = cym.dbopen('cyclus_unat_u6-ss.sqlite')
db_unat_u6 = cym.dbopen('cyclus_unat_u6.sqlite')

# %%
ev3 = cym.Evaluator(db=db_unat_u6,write=False)
u6_TS = cvi.get_transaction_timeseries(ev3,rec_list=['LWR'],nuc_list=['U236'])
# Out:
# ['SimId' 'Time']

# %%
u_tot_TS = cvi.get_transaction_timeseries(ev3,rec_list=['LWR'])
# Out:
# ['Time']

# %%
frac_TS = u6_TS/ u_tot_TS

# %%
frac_TS
# Out:
#      Time      Mass
# 0     NaN       NaN
# 1     1.0  0.000286
# 2     1.0       NaN
# 3     1.0       NaN
# 4     1.0       NaN
# 5     1.0       NaN
# 6     1.0       NaN
# 7     1.0       NaN
# 8     1.0       NaN
# 9     1.0       NaN
# 10    1.0  0.000286
# 11    1.0       NaN
# 12    1.0       NaN
# 13    1.0       NaN
# 14    1.0       NaN
# 15    1.0       NaN
# 16    1.0       NaN
# 17    1.0       NaN
# 18    1.0       NaN
# 19    1.0  0.000286
# 20    1.0       NaN
# 21    1.0       NaN
# 22    1.0       NaN
# 23    1.0       NaN
# 24    1.0       NaN
# 25    1.0       NaN
# 26    1.0       NaN
# 27    1.0       NaN
# 28    1.0  0.000286
# 29    1.0       NaN
# ..    ...       ...
# 470   1.0       NaN
# 471   1.0       NaN
# 472   1.0       NaN
# 473   1.0       NaN
# 474   1.0       NaN
# 475   1.0       NaN
# 476   1.0       NaN
# 477   1.0       NaN
# 478   1.0  0.000286
# 479   1.0       NaN
# 480   1.0       NaN
# 481   1.0       NaN
# 482   1.0       NaN
# ...

# %%
tails_u6_TS = cvi.get_transaction_timeseries(ev3,rec_list=['sink_du'],nuc_list=['U236'])
tails_u6_TS
# Out:
# ['Time']
#      Time       Mass
# 0       0   0.000000
# 1       1   0.000000
# 2       2  57.721781
# 3       3   0.000000
# 4       4   0.000000
# 5       5   0.000000
# 6       6   0.000000
# 7       7   0.000000
# 8       8   0.000000
# 9       9   0.000000
# 10     10   0.000000
# 11     11   9.620297
# 12     12   0.000000
# 13     13   0.000000
# 14     14   0.000000
# 15     15   0.000000
# 16     16   0.000000
# 17     17   0.000000
# 18     18   0.000000
# 19     19   0.000000
# 20     20   9.620297
# 21     21   0.000000
# 22     22   0.000000
# 23     23   0.000000
# 24     24   0.000000
# 25     25   0.000000
# 26     26   0.000000
# 27     27   0.000000
# 28     28   0.000000
# 29     29   9.620297
# ..    ...        ...
# 470   470   9.620297
# 471   471   0.000000
# 472   472   0.000000
# 473   473   0.000000
# 474   474   0.000000
# 475   475   0.000000
# 476   476   0.000000
# 477   477   0.000000
# 478   478   0.000000
# 479   479   9.620297
# 480   480   0.000000
# ...

# %%
tails_u_tot_TS = cvi.get_transaction_timeseries(ev3,rec_list=['sink_du'])
tails_u_tot_TS
# Out:
# ['Time']
#      Time           Mass
# 0       0       0.000000
# 1       1       0.000000
# 2       2  666575.223385
# 3       3       0.000000
# 4       4       0.000000
# 5       5       0.000000
# 6       6       0.000000
# 7       7       0.000000
# 8       8       0.000000
# 9       9       0.000000
# 10     10       0.000000
# 11     11  111095.870564
# 12     12       0.000000
# 13     13       0.000000
# 14     14       0.000000
# 15     15       0.000000
# 16     16       0.000000
# 17     17       0.000000
# 18     18       0.000000
# 19     19       0.000000
# 20     20  111095.870564
# 21     21       0.000000
# 22     22       0.000000
# 23     23       0.000000
# 24     24       0.000000
# 25     25       0.000000
# 26     26       0.000000
# 27     27       0.000000
# 28     28       0.000000
# 29     29  111095.870564
# ..    ...            ...
# 470   470  111095.870564
# 471   471       0.000000
# 472   472       0.000000
# 473   473       0.000000
# ...

# %%
tails_frac_TS = tails_u6_TS/ tails_u_tot_TS

# %%
tails_frac_TS
# Out:
#      Time      Mass
# 0     NaN       NaN
# 1     1.0       NaN
# 2     1.0  0.000087
# 3     1.0       NaN
# 4     1.0       NaN
# 5     1.0       NaN
# 6     1.0       NaN
# 7     1.0       NaN
# 8     1.0       NaN
# 9     1.0       NaN
# 10    1.0       NaN
# 11    1.0  0.000087
# 12    1.0       NaN
# 13    1.0       NaN
# 14    1.0       NaN
# 15    1.0       NaN
# 16    1.0       NaN
# 17    1.0       NaN
# 18    1.0       NaN
# 19    1.0       NaN
# 20    1.0  0.000087
# 21    1.0       NaN
# 22    1.0       NaN
# 23    1.0       NaN
# 24    1.0       NaN
# 25    1.0       NaN
# 26    1.0       NaN
# 27    1.0       NaN
# 28    1.0       NaN
# 29    1.0  0.000087
# ..    ...       ...
# 470   1.0  0.000087
# 471   1.0       NaN
# 472   1.0       NaN
# 473   1.0       NaN
# 474   1.0       NaN
# 475   1.0       NaN
# 476   1.0       NaN
# 477   1.0       NaN
# 478   1.0       NaN
# 479   1.0  0.000087
# 480   1.0       NaN
# 481   1.0       NaN
# 482   1.0       NaN
# ...
