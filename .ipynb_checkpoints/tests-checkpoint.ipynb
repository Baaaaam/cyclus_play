# %%
import cymetric as cym
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import cy_fast_timed_analysis as ana_t
#import cy_fast_analysis as ana
from cymetric import timeseries as cyts
from cymetric import graphs as cygr
# %matplotlib inline

# %%
#load db in a evaler
db = cym.dbopen('q3.h5')

# %%
ev = cym.Evaluator(db=db,write=False)

# %%
cygr.flow_graph(evaler=ev,label="mass" )

# %%
cyts.transactions(evaler=ev, senders=['PWR'])
# Out:
#      Time     Mass
# 0       0      0.0
# 1       1      0.0
# 2       2      0.0
# 3       3      0.0
# 4       4      0.0
# 5       5      0.0
# 6       6      0.0
# 7       7      0.0
# 8       8      0.0
# 9       9      0.0
# 10     10      0.0
# 11     11      0.0
# 12     12      0.0
# 13     13      0.0
# 14     14      0.0
# 15     15      0.0
# 16     16      0.0
# 17     17  30000.0
# 18     18      0.0
# 19     19      0.0
# 20     20      0.0
# 21     21      0.0
# 22     22      0.0
# 23     23      0.0
# 24     24      0.0
# 25     25      0.0
# 26     26      0.0
# 27     27      0.0
# 28     28      0.0
# 29     29      0.0
# ..    ...      ...
# 691   691      0.0
# 692   692      0.0
# 693   693      0.0
# 694   694      0.0
# 695   695      0.0
# 696   696      0.0
# 697   697      0.0
# 698   698      0.0
# 699   699      0.0
# 700   700      0.0
# 701   701  30000.0
# 702   702      0.0
# 703   703      0.0
# 704   704      0.0
# 705   705      0.0
# ...
